# %%
#Nguồn https://www.miai.vn/2019/08/05/yolo-series-1-su-dung-yolo-de-nhan-dang-doi-tuong-trong-anh/

# %%
# !gdown https://drive.google.com/uc?id=1cU_JS1ahWdNZ1ORTFt6CUoGWE8iVM546
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cU_JS1ahWdNZ1ORTFt6CUoGWE8iVM546
# To: /content/yolo_v3_beginner.zip
# 2.90MB [00:00, 45.8MB/s]

# %%
# !unzip /content/yolo_v3_beginner.zip
# Out:
# Archive:  /content/yolo_v3_beginner.zip
#    creating: yolo_v3_beginner/
#   inflating: yolo_v3_beginner/1_7SKifRP2-eiFdZoaOLovoQ.png
#  extracting: yolo_v3_beginner/1_J8KqdQiw8jr4xCrFUWQAZg.png
#   inflating: yolo_v3_beginner/cam1.png
#   inflating: yolo_v3_beginner/cam2.jpg
#   inflating: yolo_v3_beginner/cam3.jpeg
#   inflating: yolo_v3_beginner/dog.jpg
#   inflating: yolo_v3_beginner/make_train_val.py
#   inflating: yolo_v3_beginner/object-detection.jpg
#   inflating: yolo_v3_beginner/README.md
#   inflating: yolo_v3_beginner/YOLO.py
#   inflating: yolo_v3_beginner/yolov3.cfg
#   inflating: yolo_v3_beginner/yolov3.txt
#   inflating: yolo_v3_beginner/You-Only-Look-One-v3-tiny-YOLOv3-tiny-network-structure.png

# %%
# %cd yolo_v3_beginner
# Out:
# /content/yolo_v3_beginner

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2020-10-01 11:58:20--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  2.08MB/s    in 78s
#
# 2020-10-01 11:59:38 (3.05 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
import cv2 
from google.colab.patches import cv2_imshow

image = cv2.imread("cam1.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768 at 0x7F9974D21940>

# %%
# !python YOLO.py -i cam1.png -cl yolov3.txt -w yolov3.weights -c yolov3.cfg
# Out:
# YOLO Execution time: 0.05192136764526367

# %% [markdown]
# # TỰ CHẠY HUẤN LUYỆN 1 VẬT THỂ BẤT KỲ

# %%
########### NGUỒN https://www.miai.vn/2020/05/25/yolo-series-train-yolo-v4-train-tren-colab-chi-tiet-va-day-du-a-z/

# %%
# %cd /content
# Out:
# /content

# %%
# Step 2. Tai ma nguon YOLO ve drive
# !rm -rf darknet
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14321, done.
# remote: Total 14321 (delta 0), reused 0 (delta 0), pack-reused 14321
# Receiving objects: 100% (14321/14321), 12.86 MiB | 6.54 MiB/s, done.
# Resolving deltas: 100% (9772/9772), done.

# %% [markdown]
# #Step 3. Các bạn tải file
# - yolov4-custom.cfg từ máy tính lên Google drive, thư mục darknet/cfg
# - data.zip lên thư mục  của darknet/data.
# - Makefile lên thư mục darknet

# %%
# Step 4. Giải nén file data
# %cd /content/darknet
# !rm -r data
# !mkdir data
# %cd data
# !gdown https://drive.google.com/uc?id=1ZZx_a3D73Vf1UBtcDJnyjXeYbXA5shdq
# !unzip data.zip
# Out:
# /content/darknet
# /content/darknet/data
# Downloading...
# From: https://drive.google.com/uc?id=1ZZx_a3D73Vf1UBtcDJnyjXeYbXA5shdq
# To: /content/darknet/data/data.zip
# 65.3MB [00:00, 206MB/s]
# Archive:  data.zip
#   inflating: 000001.jpg
#   inflating: 000001.txt
#   inflating: 000002.jpg
#   inflating: 000002.txt
#   inflating: 000003.jpg
#   inflating: 000004.jpg
#   inflating: 000004.txt
#   inflating: 000005.jpg
#   inflating: 000005.txt
#   inflating: 000006.jpg
#   inflating: 000006.txt
#   inflating: 000007.jpg
#   inflating: 000008.jpg
#   inflating: 000008.txt
#   inflating: 000009.jpg
#   inflating: 000009.txt
#   inflating: 000011.jpg
#   inflating: 000011.txt
#   inflating: 000012.jpg
#   inflating: 000012.txt
#   inflating: 000013.jpg
#   inflating: 000013.txt
#   inflating: 000014.jpg
#   inflating: 000014.txt
#   inflating: 000015.jpg
#   inflating: 000015.txt
#   inflating: 000016.jpg
#   inflating: 000016.txt
#   inflating: 000017.jpg
#   inflating: 000018.jpg
# ...

# %%
# !rm -r /content/darknet/Makefile
# !rm -r /content/darknet/cfg/yolov4-custom.cfg

# %%
# %cd /content/darknet/
# !gdown https://drive.google.com/uc?id=1qnSYuGzt7h90C0mQsQamPdtQFoHIBr3K
# Out:
# /content/darknet
# Downloading...
# From: https://drive.google.com/uc?id=1qnSYuGzt7h90C0mQsQamPdtQFoHIBr3K
# To: /content/darknet/Makefile
# 100% 5.66k/5.66k [00:00<00:00, 10.5MB/s]

# %%
# %cd /content/darknet/cfg/
# !gdown https://drive.google.com/uc?id=1LeJns_OWi4RQZ4JhBp0j6YES-ZCHwrHo
# Out:
# /content/darknet/cfg
# Downloading...
# From: https://drive.google.com/uc?id=1LeJns_OWi4RQZ4JhBp0j6YES-ZCHwrHo
# To: /content/darknet/cfg/yolov4-custom.cfg
# 100% 12.2k/12.2k [00:00<00:00, 22.6MB/s]

# %%
# Step 5. Tạo file yolo.names
# %cd /content/darknet
# !echo "fire" > yolo.names
# Out:
# /content/darknet

# %%
# Step 6. Tạo file train.txt và val.txt
# %cd /content/darknet

import glob2
import math  
import os
import numpy as np

files = []
for ext in ["*.png", "*.jpeg", "*.jpg"]:
  image_files = glob2.glob(os.path.join("data", ext))
  files += image_files

nb_val = math.floor(len(files)*0.2)
rand_idx = np.random.randint(0, len(files), nb_val)

# Tạo file train.txt
with open("train.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')

# Tạo file vali.txt
with open("val.txt", "w") as f:
  for idx in np.arange(len(files)):
    if (idx in rand_idx) and (os.path.exists(files[idx][:-3] + "txt")):
      f.write(files[idx]+'\n')
# Out:
# /content/darknet

# %%
# Step 7. Tạo file yolo.data
# %cd /content/darknet
# !mkdir backup
# !echo classes=1 > yolo.data
# !echo train=train.txt >> yolo.data
# !echo valid=valid.txt >> yolo.data
# !echo names=yolo.names >> yolo.data
# !echo backup=backup >> yolo.data
# Out:
# /content/darknet

# %%
# Step 8. Make darknet
# %cd /content/darknet
# !rm darknet
# !make
# Out:
# /content/darknet
# rm: cannot remove 'darknet': No such file or directory
# mkdir -p ./obj/
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ...

# %%
# Step 9. Download pretrain weight
# %cd /content/darknet
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# Step 10. Train
# %cd /content/darknet
# !./darknet detector train yolo.data cfg/yolov4-custom.cfg yolov4.conv.137 -dont_show
